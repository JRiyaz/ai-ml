# %%
# Read data from Google drive

from google.colab import drive
import pandas as pd

# Mount the drive
drive.mount('/content/drive')

# Read CSV file
# df = pd.read_csv('/content/drive/MyDrive/Colab Notebooks/healthcare.csv')
df = pd.read_csv('/content/drive/MyDrive/ai-ml/data/sachins_odi_career.csv')
df.head()

# %%
# Upload or Read data from sample_data from Google Collab
import pandas as pd

df = pd.read_csv("sample_data/california_housing_test.csv")
df.head()
# Out:
#    longitude  latitude  housing_median_age  total_rooms  total_bedrooms  \
# 0    -122.05     37.37                27.0       3885.0           661.0
# 1    -118.30     34.26                43.0       1510.0           310.0
# 2    -117.81     33.78                27.0       3589.0           507.0
# 3    -118.36     33.82                28.0         67.0            15.0
# 4    -119.67     36.33                19.0       1241.0           244.0
#
#    population  households  median_income  median_house_value
# 0      1537.0       606.0         6.6085            344700.0
# 1       809.0       277.0         3.5990            176500.0
# 2      1484.0       495.0         5.7934            270500.0
# 3        49.0        11.0         6.1359            330000.0
# 4       850.0       237.0         2.9375             81700.0

# %%
# Read data from Google Colab runtime (must upload the data before using)
import pandas as pd

df = pd.read_csv("data.csv")
df.head()
# Out:
#    id first_name last_name                      email  gender birth_date  \
# 0   1       Veda     Pavey      vpavey0@delicious.com  Female   7/7/2017
# 1   2     Phylis   Fritzer    pfritzer1@posterous.com  Female  9/29/2014
# 2   3        Tim     Bigby      tbigby2@amazonaws.com    Male  5/11/2025
# 3   4    Sherill    Arkley  sarkley3@seattletimes.com  Female  3/11/2013
# 4   5      Jared   Burdytt                        NaN    Male  9/28/2009
#
#   time_of_birth is_active     address    country        timezone
# 0      12:44:48     False         NaN  Indonesia    Asia/Jakarta
# 1      17:15:20     False         NaN  Indonesia    Asia/Jakarta
# 2       7:07:32     False   7th Floor      China  Asia/Chongqing
# 3      21:42:11     False    Suite 30      China   Asia/Shanghai
# 4      22:41:39      True  18th Floor      China  Asia/Chongqing

# %%
# Read data from Github
import pandas as pd

#df = pd.read_csv("https://raw.github.com/JRiyaz/data-science/main/data/data.csv")
df = pd.read_csv("https://raw.github.com/JRiyaz/ai-ml/main/data/data.csv")
df.head()
# Out:
#    id first_name last_name                      email  gender birth_date  \
# 0   1       Veda     Pavey      vpavey0@delicious.com  Female   7/7/2017
# 1   2     Phylis   Fritzer    pfritzer1@posterous.com  Female  9/29/2014
# 2   3        Tim     Bigby      tbigby2@amazonaws.com    Male  5/11/2025
# 3   4    Sherill    Arkley  sarkley3@seattletimes.com  Female  3/11/2013
# 4   5      Jared   Burdytt                        NaN    Male  9/28/2009
#
#   time_of_birth is_active     address    country        timezone
# 0      12:44:48     False         NaN  Indonesia    Asia/Jakarta
# 1      17:15:20     False         NaN  Indonesia    Asia/Jakarta
# 2       7:07:32     False   7th Floor      China  Asia/Chongqing
# 3      21:42:11     False    Suite 30      China   Asia/Shanghai
# 4      22:41:39      True  18th Floor      China  Asia/Chongqing

# %%
# !python --version
# Out:
# Python 3.12.11

# %%
# !pip --version
# Out:
# pip 24.1.2 from /usr/local/lib/python3.12/dist-packages/pip (python 3.12)

# %%
# !pip list

# %%
# !sudo apt-get upgrade -y
# Out:
# Reading package lists... Done
# Building dependency tree... Done
# Reading state information... Done
# Calculating upgrade... Done
# The following packages have been kept back:
#   libcudnn9-cuda-12 libcudnn9-dev-cuda-12 libnccl-dev libnccl2
# The following packages will be upgraded:
#   base-files binutils binutils-common binutils-x86-64-linux-gnu
#   cuda-toolkit-12-config-common cuda-toolkit-config-common e2fsprogs
#   libbinutils libc-bin libcap2 libctf-nobfd0 libctf0 libext2fs2 libgnutls30
#   libldap-2.5-0 libpam-modules libpam-modules-bin libpam-runtime libpam0g
#   libperl5.34 libseccomp2 libss2 libtasn1-6 libudev1 linux-libc-dev logsave
#   openssl perl perl-base perl-modules-5.34 python3-pkg-resources
# 31 upgraded, 0 newly installed, 0 to remove and 4 not upgraded.
# Need to get 19.3 MB of archives.
# After this operation, 339 kB of additional disk space will be used.
# ...

# %%
# !cat /etc/os-release
# Out:
# PRETTY_NAME="Ubuntu 22.04.5 LTS"
# NAME="Ubuntu"
# VERSION_ID="22.04"
# VERSION="22.04.5 LTS (Jammy Jellyfish)"
# VERSION_CODENAME=jammy
# ID=ubuntu
# ID_LIKE=debian
# HOME_URL="https://www.ubuntu.com/"
# SUPPORT_URL="https://help.ubuntu.com/"
# BUG_REPORT_URL="https://bugs.launchpad.net/ubuntu/"
# PRIVACY_POLICY_URL="https://www.ubuntu.com/legal/terms-and-policies/privacy-policy"
# UBUNTU_CODENAME=jammy

# %%
# !curl -LsSf https://astral.sh/uv/install.sh | sh
# Out:
# downloading uv 0.6.12 x86_64-unknown-linux-gnu
# no checksums to verify
# installing to /usr/local/bin
#   uv
#   uvx
# everything's installed!

# %%
# !ifconfig
# Out:
# eth0: flags=4163<UP,BROADCAST,RUNNING,MULTICAST>  mtu 1500
#         inet 172.28.0.12  netmask 255.255.0.0  broadcast 172.28.255.255
#         ether 02:42:ac:1c:00:0c  txqueuelen 0  (Ethernet)
#         RX packets 3407  bytes 47657516 (47.6 MB)
#         RX errors 0  dropped 0  overruns 0  frame 0
#         TX packets 1946  bytes 447439 (447.4 KB)
#         TX errors 0  dropped 0 overruns 0  carrier 0  collisions 0
#
# lo: flags=73<UP,LOOPBACK,RUNNING>  mtu 65536
#         inet 127.0.0.1  netmask 255.0.0.0
#         loop  txqueuelen 1000  (Local Loopback)
#         RX packets 7217  bytes 2230742 (2.2 MB)
#         RX errors 0  dropped 0  overruns 0  frame 0
#         TX packets 7217  bytes 2230742 (2.2 MB)
#         TX errors 0  dropped 0 overruns 0  carrier 0  collisions 0

# %%
import torch, numpy

print(torch.__version__, numpy.__version__)
# Out:
# 2.6.0+cu124 2.0.2

# %%
# !uv --version
# Out:
# uv 0.6.12

# %%
# !uv python list
# Out:
# cpython-3.14.0a6+freethreaded-linux-x86_64-gnu    <download available>
# cpython-3.14.0a6-linux-x86_64-gnu                 <download available>
# cpython-3.13.2+freethreaded-linux-x86_64-gnu      <download available>
# cpython-3.13.2-linux-x86_64-gnu                   <download available>
# cpython-3.12.11-linux-x86_64-gnu                  /usr/local/bin/python
# cpython-3.12.11-linux-x86_64-gnu                  /usr/bin/python3.12
# cpython-3.12.11-linux-x86_64-gnu                  /usr/bin/python3 -> /etc/alternatives/python3
# cpython-3.12.11-linux-x86_64-gnu                  /bin/python3.12
# cpython-3.12.11-linux-x86_64-gnu                  /bin/python3 -> /etc/alternatives/python3
# cpython-3.12.9-linux-x86_64-gnu                   <download available>
# cpython-3.11.11-linux-x86_64-gnu                  <download available>
# cpython-3.10.16-linux-x86_64-gnu                  <download available>
# cpython-3.10.12-linux-x86_64-gnu                  /usr/bin/python3.10
# ...

# %%
# !which py

# %%
# !uv python list
# Out:
# cpython-3.14.0a6+freethreaded-linux-x86_64-gnu    <download available>
# cpython-3.14.0a6-linux-x86_64-gnu                 <download available>
# cpython-3.13.2+freethreaded-linux-x86_64-gnu      <download available>
# cpython-3.13.2-linux-x86_64-gnu                   <download available>
# cpython-3.12.9-linux-x86_64-gnu                   /usr/local/bin/python
# cpython-3.12.9-linux-x86_64-gnu                   /usr/bin/python3.11 -> /usr/bin/py
# cpython-3.12.9-linux-x86_64-gnu                   /usr/bin/python3 -> /etc/alternatives/python3
# cpython-3.12.9-linux-x86_64-gnu                   /usr/bin/python -> /usr/bin/py
# cpython-3.12.9-linux-x86_64-gnu                   /bin/python3.11 -> /usr/bin/py
# cpython-3.12.9-linux-x86_64-gnu                   /bin/python3 -> /etc/alternatives/python3
# cpython-3.12.9-linux-x86_64-gnu                   /bin/python -> /usr/bin/py
# ...

# %%
# !update-alternatives --install /usr/bin/py py /root/.local/share/uv/python/cpython-3.12.9-linux-x86_64-gnu/bin/python3.12 1
# Out:
# update-alternatives: using /root/.local/share/uv/python/cpython-3.12.9-linux-x86_64-gnu/bin/python3.12 to provide /usr/bin/py (py) in auto mode

# %%
# !ln -sf /usr/bin/py /usr/bin/python

# %%
# !ln -sf /usr/bin/py /usr/bin/python3.11

# %%
# !ls -l /etc/alternatives
# Out:
# total 28
# lrwxrwxrwx 1 root root  21 Apr  3 13:17 aclocal -> /usr/bin/aclocal-1.16
# lrwxrwxrwx 1 root root  37 Apr  3 13:17 aclocal.1.gz -> /usr/share/man/man1/aclocal-1.16.1.gz
# lrwxrwxrwx 1 root root  22 Apr  3 13:17 automake -> /usr/bin/automake-1.16
# lrwxrwxrwx 1 root root  38 Apr  3 13:17 automake.1.gz -> /usr/share/man/man1/automake-1.16.1.gz
# lrwxrwxrwx 1 root root  13 Jun 27  2024 awk -> /usr/bin/mawk
# lrwxrwxrwx 1 root root  52 Apr  3 13:17 blas64.pc-x86_64-linux-gnu -> /usr/lib/x86_64-linux-gnu/pkgconfig/mkl-sdl-ilp64.pc
# lrwxrwxrwx 1 root root  69 Apr  3 13:17 blas.pc-x86_64-linux-gnu -> /usr/lib/x86_64-linux-gnu/openblas-pthread/pkgconfig/blas-openblas.pc
# lrwxrwxrwx 1 root root  12 Jul 10  2024 c++ -> /usr/bin/g++
# lrwxrwxrwx 1 root root  16 Jul 10  2024 c89 -> /usr/bin/c89-gcc
# lrwxrwxrwx 1 root root  16 Jul 10  2024 c99 -> /usr/bin/c99-gcc
# lrwxrwxrwx 1 root root  28 Apr  3 13:17 cblas64.h-x86_64-linux-gnu -> /usr/include/mkl/mkl_cblas.h
# ...

# %%
# !python3 --version
# Out:
# Python 3.11.11

# %%
import platform

print(platform.python_version())
# Out:
# 3.12.11
